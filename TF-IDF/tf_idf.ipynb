# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import json
from sklearn.metrics.pairwise import euclidean_distances

# %%
movies_data = pd.read_csv('tmdb_5000_movies.csv')
movies_data.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %%
movies_data["genres"]= movies_data["genres"].apply(lambda x: json.loads(x))
movies_data["keywords"]= movies_data["keywords"].apply(lambda x: json.loads(x))

# %%
# Remove row if   keyword and genres are empty
movies_data=movies_data[movies_data[["genres","keywords"]].apply(lambda a:(len(a['genres'])>0) | (len(a['keywords']) >0) ,axis=1)]

# %%
def get_genres_keywords(data):
    words = []
    genres = data["genres"]
    keywords = data["keywords"]
    genres_keywords = genres + keywords 
    for value in genres_keywords:
        words.append(value["name"])
    
    return " ".join(words)

# %%
movies_data["keywords_genres"] = movies_data.apply(get_genres_keywords,axis=1)

# %%
vectorizer = TfidfVectorizer()
vector_data= vectorizer.fit_transform(movies_data["keywords_genres"]).toarray()
test_movie_data =  vectorizer.transform([movies_data["keywords_genres"][0]]).toarray()
vectorizer.get_feature_names_out()
# Out:
# array(['11', '15th', '16th', ..., '卧底肥妈', '绝地奶霸', '超级妈妈'], dtype=object)

# %%
nearest_movies = [x[0] for x in euclidean_distances(vector_data, test_movie_data)]
nearest_movies= pd.DataFrame(nearest_movies,columns=["distance"])
nearest_movies["Moive_index"] = movies_data.index

nearest_movies.sort_values(by="distance",inplace=True)
nearest_movies = nearest_movies.iloc[:5,:]

# %%
# recommended Movies based on the test movie
movies_data.iloc[list(nearest_movies["Moive_index"])]
# Out:
#          budget                                             genres  \
# 0     237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 278   100000000  [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
# 2403   18500000  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 838    50000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 541    75000000  [{'id': 28, 'name': 'Action'}, {'id': 10752, '...
#
#                          homepage     id  \
# 0     http://www.avatarmovie.com/  19995
# 278                           NaN    869
# 2403                          NaN    679
# 838                           NaN   8077
# 541    http://www.wb-soldier.com/   9425
#
#                                                keywords original_language  \
# 0     [{'id': 1463, 'name': 'culture clash'}, {'id':...                en
# 278   [{'id': 690, 'name': 'gorilla'}, {'id': 1826, ...                en
# 2403  [{'id': 803, 'name': 'android'}, {'id': 1603, ...                en
# 838   [{'id': 378, 'name': 'prison'}, {'id': 803, 'n...                en
# 541   [{'id': 1826, 'name': 'space marine'}, {'id': ...                en
#
#           original_title                                           overview  \
# 0                 Avatar  In the 22nd century, a paraplegic Marine is di...
# 278   Planet of the Apes  After a spectacular crash-landing on an unchar...
# 2403              Aliens  When Ripley's lifepod is found by a salvage cr...
# 838               Alien³  After escaping with Newt and Hicks from the al...
# 541              Soldier  Sergeant Todd is a veteran soldier for an elit...
#
#       popularity                               production_companies  ...  \
# 0     150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 278    51.188633  [{"name": "Twentieth Century Fox Film Corporat...  ...
# 2403   67.660940  [{"name": "Twentieth Century Fox Film Corporat...  ...
# 838    45.856409  [{"name": "Twentieth Century Fox Film Corporat...  ...
# 541    11.873856  [{"name": "Impact Pictures", "id": 248}, {"nam...  ...
#
#      release_date     revenue  runtime  \
# 0      2009-12-10  2787965087    162.0
# 278    2001-07-25   362211740    119.0
# 2403   1986-07-18   183316455    137.0
# 838    1992-05-22   159773545    114.0
# 541    1998-10-23    14567883     99.0
#
#                                        spoken_languages    status  \
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 278            [{"iso_639_1": "en", "name": "English"}]  Released
# 2403           [{"iso_639_1": "en", "name": "English"}]  Released
# 838            [{"iso_639_1": "en", "name": "English"}]  Released
# 541            [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline               title  \
# 0                           Enter the World of Pandora.              Avatar
# 278            You'll be sorry you were ever born human  Planet of the Apes
# 2403                                 This Time It's War              Aliens
# 838                                  The bitch is back.              Alien³
# 541   Left for dead on a remote planet for obsolete ...             Soldier
#
#      vote_average  vote_count  \
# 0             7.2       11800
# 278           5.6        1243
# 2403          7.7        3220
# 838           6.2        1633
# 541           6.1         221
#
#                                         keywords_genres
# 0     Action Adventure Fantasy Science Fiction cultu...
# 278   Thriller Science Fiction Action Adventure gori...
# 2403  Horror Action Thriller Science Fiction android...
# 838   Science Fiction Action Horror prison android s...
# 541   Action War Science Fiction space marine dystop...
#
# [5 rows x 21 columns]
